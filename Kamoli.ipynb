# %% [markdown]
# <a href="https://colab.research.google.com/github/El-awwal/demo/blob/main/Kamoli.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('fashion dataset.csv')

# %%
data.head()
# Out:
#          p_id                                               name   price  \
# 0   1518329.0   Dupatta Bazaar White Embroidered Chiffon Dupatta   899.0
# 1   5829334.0  Roadster Women Mustard Yellow Solid Hooded Swe...  1199.0
# 2  10340119.0  Inddus Peach-Coloured & Beige Unstitched Dress...  5799.0
# 3  10856380.0            SASSAFRAS Women Black Parallel Trousers  1499.0
# 4  12384822.0  Kotty Women Black Wide Leg High-Rise Clean Loo...  1999.0
#
#     colour           brand  ratingCount  avg_rating  \
# 0    White  Dupatta Bazaar       1321.0    4.548827
# 1  Mustard        Roadster       5462.0    4.313255
# 2    Peach          Inddus        145.0    4.068966
# 3    Black       SASSAFRAS       9124.0    4.147523
# 4    Black           Kotty      12260.0    4.078467
#
#                                          description  \
# 0  White embroidered&nbsp;dupattaChiffon<br>Hand-...
# 1  Mustard yellow solid sweatshirt, has a hood, t...
# ...

# %%
data.describe()
# Out:
#                p_id         price   ratingCount   avg_rating
# count  1.431100e+04  14310.000000   6581.000000  6581.000000
# mean   1.569129e+07   2964.168484    184.479410     4.101226
# std    3.153525e+06   2564.014851    782.501137     0.475633
# min    7.016600e+04    169.000000      1.000000     1.000000
# 25%    1.413618e+07   1599.000000      9.000000     3.888889
# 50%    1.638217e+07   2200.000000     23.000000     4.180822
# 75%    1.808452e+07   3495.000000     80.000000     4.392857
# max    1.941576e+07  47999.000000  21274.000000     5.000000

# %%
data = data.drop_duplicates()
data
# Out:
#              p_id                                               name   price  \
# 0       1518329.0   Dupatta Bazaar White Embroidered Chiffon Dupatta   899.0
# 1       5829334.0  Roadster Women Mustard Yellow Solid Hooded Swe...  1199.0
# 2      10340119.0  Inddus Peach-Coloured & Beige Unstitched Dress...  5799.0
# 3      10856380.0            SASSAFRAS Women Black Parallel Trousers  1499.0
# 4      12384822.0  Kotty Women Black Wide Leg High-Rise Clean Loo...  1999.0
# ...           ...                                                ...     ...
# 14324  17029604.0  The Chennai Silks Pink & Silver-Toned Floral Z...  3999.0
# 14325  17600212.0  Kinder Kids Girls Blue & Green Printed Foil Pr...  2050.0
# 14326  18159266.0  KLOTTHE Women Green & Black Floral Printed Pal...  1659.0
# 14327  18921114.0             InWeave Women Red Printed A-Line Skirt  2399.0
# 14328  19361058.0      BoStreet Women Navy Blue Tapered Fit Trousers  2599.0
#
# ...

# %%
data = data.dropna()
data = data.drop(data[['description','p_attributes']],axis=1)
data
# Out:
#              p_id                                               name   price  \
# 0       1518329.0   Dupatta Bazaar White Embroidered Chiffon Dupatta   899.0
# 1       5829334.0  Roadster Women Mustard Yellow Solid Hooded Swe...  1199.0
# 2      10340119.0  Inddus Peach-Coloured & Beige Unstitched Dress...  5799.0
# 3      10856380.0            SASSAFRAS Women Black Parallel Trousers  1499.0
# 4      12384822.0  Kotty Women Black Wide Leg High-Rise Clean Loo...  1999.0
# ...           ...                                                ...     ...
# 14309  14173362.0  STREET 9 Black Puff Sleeves Blouson Crop Pleat...  1999.0
# 14312  17122946.0  Moda Rapido Women Blue Straight Fit High-Rise ...  2299.0
# 14320  14235030.0  Indo Era Women Black Floral Printed Pure Cotto...  3499.0
# 14322  16835446.0      Allen Solly Woman Women Blue Skinny Fit Jeans  1999.0
# 14323  16944668.0   Berrylush Women Pretty Pink Romantic Florals Top  1799.0
#
# ...

# %%
data.columns = data.columns.str.title()
data
# Out:
#              P_Id                                               Name   Price  \
# 0       1518329.0   Dupatta Bazaar White Embroidered Chiffon Dupatta   899.0
# 1       5829334.0  Roadster Women Mustard Yellow Solid Hooded Swe...  1199.0
# 2      10340119.0  Inddus Peach-Coloured & Beige Unstitched Dress...  5799.0
# 3      10856380.0            SASSAFRAS Women Black Parallel Trousers  1499.0
# 4      12384822.0  Kotty Women Black Wide Leg High-Rise Clean Loo...  1999.0
# ...           ...                                                ...     ...
# 14309  14173362.0  STREET 9 Black Puff Sleeves Blouson Crop Pleat...  1999.0
# 14312  17122946.0  Moda Rapido Women Blue Straight Fit High-Rise ...  2299.0
# 14320  14235030.0  Indo Era Women Black Floral Printed Pure Cotto...  3499.0
# 14322  16835446.0      Allen Solly Woman Women Blue Skinny Fit Jeans  1999.0
# 14323  16944668.0   Berrylush Women Pretty Pink Romantic Florals Top  1799.0
#
# ...

# %%
data.index = data['Brand']
data.sort_index()
# Out:
#                   P_Id                                               Name  \
# Brand
# 20Dresses   11844068.0  20Dresses Women Blue Solid Batwing Sleeved Bas...
# 20Dresses   13611428.0  20Dresses Women Blue & Peach-Coloured Comfort ...
# 20Dresses   12290254.0       20Dresses Pink & White Floral Print Crop Top
# 20Dresses   15045314.0  20Dresses Women Maroon Flared High-Rise Parall...
# 20Dresses   16642076.0                     20Dresses Black Basic Jumpsuit
# ...                ...                                                ...
# trueBrowns  10335143.0  trueBrowns Women White Self Design Kurta with ...
# urSense     15576250.0      urSense Women Black Printed Embroidered Shrug
# urSense     16402022.0  urSense Women Black Geometric Tailored Jacket ...
# wild U      15639490.0  wild U Navy Blue Tulip Sleeves Plus Size Basic...
# zebu        12895196.0           zebu Women Grey Printed Pullover Sweater
#
#              Price     Colour       Brand  Ratingcount  Avg_Rating
# ...
